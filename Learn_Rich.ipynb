# %% [markdown]
# <a href="https://colab.research.google.com/github/Anannya-Vyas/numpy/blob/main/Learn_Rich.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import rich
from rich import print
from rich.console import Console

rich.print(sys.version)
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
rich.print("[red bold on yellow]hello world[/red bold on yellow]")
# Out:
# hello world

# %%
from rich.prompt import Prompt
from rich import print

a = Prompt.ask("[bold green]Enter a number[/bold green]")
int(a)
print(f"You entered: [yellow]{a}[/yellow]")
# Out:
# Enter a number:
# 5
# You entered: 5

# %%
print("hi")
# Out:
# hi

# %%
# Use Console for advanced printing control.
from rich.console import Console
console = Console()
console.print("[cyan]Hello via Console[/cyan]")
# Out:
# Hello via Console

# %%
from rich.console import Console

# create a console object
console = Console()

# simple styled printing
console.print("Hello [bold green]World[/bold green]!")

# multiple styles
console.print("[yellow]Warning:[/yellow] Low disk space")

# print with background
console.print("[white on blue] Inverted Colors [/white on blue]")
# Out:
# Hello World!
# ...
#  Inverted Colors

# %%
from rich.pretty import pretty_repr
from rich import print

data = {"name": "Ali", "age": 22, "skills": ["Python", "ML", "Rich"]}
print(data)  # auto-colored, pretty JSON-like
# Out:
# {'name': 'Ali', 'age': 22, 'skills': ['Python', 'ML', 'Rich']}

# %%
from rich.table import Table
from rich.console import Console

console = Console()
table = Table(title="Student Scores")

table.add_column("Name", style="bold magenta")
table.add_column("Math", justify="center")
table.add_column("Science", justify="center")

table.add_row("Ali", "95", "89")
table.add_row("Sara", "88", "92")

console.print(table)
# Out:
#      Student Scores
# ┏━━━━━━┳━━━━━━┳━━━━━━━━━┓
# ┃ Name ┃ Math ┃ Science ┃
# ┡━━━━━━╇━━━━━━╇━━━━━━━━━┩
# │ Ali  │  95  │   89    │
# │ Sara │  88  │   92    │
# └──────┴──────┴─────────┘

# %%
from rich import print
import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_test.csv")

console.print(df.describe())
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
import time
import pandas as pd
from rich.progress import track

df = pd.DataFrame({"x": range(5)})

for i in track(df["x"], description="Processing rows..."):
    time.sleep(1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from rich import print

def greet(name='user'):
    print(f"[green on black]Hello {name}![/green on black]")

greet("Ali")
greet("Sara")
greet()
# Out:
# Hello Ali!
# Hello Sara!
# Hello user!

# %%
from rich.console import Console
from rich.syntax import Syntax

console = Console()
code = 'print("Hello World")'
syntax = Syntax(code, "python", theme="monokai", line_numbers=True)
console.print(syntax)
# Out:
#   1 print("Hello World")

# %%
from rich.console import Console
from rich.markdown import Markdown

console = Console()
md = Markdown("""
# Rich Markdown Demo
This is **bold**, this is *italic*, and this is `inline code`.
- Item 1
- Item 2
""")

console.print(md)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                               Rich Markdown Demo                                                ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# This is bold, this is italic, and this is inline code.
#
#  • Item 1
#  • Item 2

# %%
from rich import print
# Rich supports hundreds of emojis and Unicode symbols.
print("[bold magenta]🎉 Success![/bold magenta]")
print("[red]❌ Error occurred[/red]")
print("[cyan]ℹ Info message[/cyan]")
# Out:
# 🎉 Success!
# ❌ Error occurred
# ℹ Info message

# %%
# Replace Python’s logging with colorful, readable logs.

import logging
from rich.logging import RichHandler
logging.basicConfig(level="INFO", handlers=[RichHandler()])
log = logging.getLogger("rich")
log.info("Info message")
log.error("Error message")
# Goal: Debug large projects efficiently.
# Out:
# ERROR:rich:Error message
